# %% [markdown]
# ## Import

# %%
import os

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/home/eiroamd/Documents/IH/Ironhack Data Analytics.json"

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()

# %% [markdown]
# ## Challenge 1

# %% [markdown]
# ### Step 1

# %%
query1 = """
SELECT
    a.au_id,
    t_a.title_id,
    ((t.price * s.qty)*(t.royalty/100)*(t_a.royaltyper/100)) AS sales_royalty
    
FROM
    `ironhack-data-analytics.publications.authors` a
INNER JOIN
    `ironhack-data-analytics.publications.titleauthor` t_a
USING 
    (au_id)

LEFT JOIN
    `ironhack-data-analytics.publications.titles` t
USING
    (title_id)

INNER JOIN
    `ironhack-data-analytics.publications.sales` s
USING
    (title_id)

GROUP BY
    s.qty,
    t.royalty,
    t_a.royaltyper,
    t.price,
    a.au_id,
    t_a.title_id
    
ORDER BY
    t_a.title_id
"""

# %%
query_job = client.query(query=query1)
df = query_job.to_dataframe()
df.head(20)
# Out:
#           au_id title_id  sales_royalty
# 0   213-46-8915   BU1032          3.998
# 1   213-46-8915   BU1032          7.996
# 2   409-56-7008   BU1032          5.997
# 3   409-56-7008   BU1032         11.994
# 4   724-80-9391   BU1111         17.925
# 5   267-41-2394   BU1111         11.950
# 6   213-46-8915   BU2075         25.116
# 7   274-80-9391   BU7832         29.985
# 8   712-45-1867   MC2222         23.988
# 9   899-46-2035   MC3021          4.485
# 10  722-51-5454   MC3021         13.455
# 11  899-46-2035   MC3021          2.691
# 12  722-51-5454   MC3021          8.073
# 13  238-95-7766   PC1035        110.160
# 14  846-92-7186   PC8888         50.000
# 15  427-17-2319   PC8888         50.000
# 16  756-30-7391   PS1372         32.385
# 17  724-80-9391   PS1372         10.795
# 18  998-72-3567   PS2091          1.971
# 19  899-46-2035   PS2091         13.140

# %% [markdown]
# ### Step 2

# %%
query2 = """

SELECT
    title_id,
    au_id,
    SUM(sales_royalty) AS agg_royalties

FROM
(SELECT
    a.au_id,
    t_a.title_id,
    ((t.price * s.qty)*(t.royalty/100)*(t_a.royaltyper/100)) AS sales_royalty

FROM
    `ironhack-data-analytics.publications.authors` a
INNER JOIN
    `ironhack-data-analytics.publications.titleauthor` t_a
USING 
    (au_id)

LEFT JOIN
    `ironhack-data-analytics.publications.titles` t
USING
    (title_id)

INNER JOIN
    `ironhack-data-analytics.publications.sales` s
USING
    (title_id)

GROUP BY
    s.qty,
    t.royalty,
    t_a.royaltyper,
    t.price,
    a.au_id,
    t_a.title_id
    
ORDER BY
    t_a.title_id) royalties

GROUP BY
    au_id,
    title_id
ORDER BY
    title_id
"""

# %%
query_job = client.query(query=query2)
df = query_job.to_dataframe()
df.head(20)
# Out:
#    title_id        au_id  agg_royalties
# 0    BU1032  213-46-8915         11.994
# 1    BU1032  409-56-7008         17.991
# 2    BU1111  267-41-2394         11.950
# 3    BU1111  724-80-9391         17.925
# 4    BU2075  213-46-8915         25.116
# 5    BU7832  274-80-9391         29.985
# 6    MC2222  712-45-1867         23.988
# 7    MC3021  722-51-5454         21.528
# 8    MC3021  899-46-2035          7.176
# 9    PC1035  238-95-7766        110.160
# 10   PC8888  427-17-2319         50.000
# 11   PC8888  846-92-7186         50.000
# 12   PS1372  724-80-9391         10.795
# 13   PS1372  756-30-7391         32.385
# 14   PS2091  899-46-2035         70.956
# 15   PS2091  998-72-3567         70.956
# 16   PS2106  998-72-3567         17.500
# 17   PS3333  172-32-1176         29.985
# 18   PS7777  486-29-1786         19.975
# 19   TC3218  807-91-6654         83.800

# %% [markdown]
# ### Step 3

# %%
query3 = """
SELECT
    au_id,
    advance + agg_royalties AS total_profit

FROM
(SELECT
    title_id,
    au_id,
    advance,
    SUM(sales_royalty) as agg_royalties

FROM
(SELECT
    a.au_id,
    t_a.title_id,
    t.advance,
    ((t.price * s.qty)*(t.royalty/100)*(t_a.royaltyper/100)) AS sales_royalty

FROM
    `ironhack-data-analytics.publications.authors` a
INNER JOIN
    `ironhack-data-analytics.publications.titleauthor` t_a
USING 
    (au_id)

LEFT JOIN
    `ironhack-data-analytics.publications.titles` t
USING
    (title_id)

INNER JOIN
    `ironhack-data-analytics.publications.sales` s
USING
    (title_id)

GROUP BY
    s.qty,
    t.royalty,
    t_a.royaltyper,
    t.price,
    a.au_id,
    t_a.title_id,
    t.advance
    
ORDER BY
    t_a.title_id) royalties

GROUP BY
    au_id,
    title_id,
    advance
    
ORDER BY
    title_id) aggregated_royalties

GROUP BY
    au_id,
    advance,
    agg_royalties

ORDER BY
    total_profit DESC
LIMIT
    3
"""

# %%
query_job = client.query(query=query3)
df = query_job.to_dataframe()
df.head(20)
# Out:
#          au_id  total_profit
# 0  722-51-5454     15021.528
# 1  899-46-2035     15007.176
# 2  213-46-8915     10150.116

# %% [markdown]
# ## Challenge 2

# %%
query4 = """
CREATE TABLE `ironhack-data-analytics.publications.most_profiting_authors_dani`
AS( SELECT 
    au_id,
    advance + agg_royalties AS profits

FROM
(SELECT
    title_id,
    au_id,
    advance,
    SUM(sales_royalty) as agg_royalties

FROM
(SELECT
    a.au_id,
    t_a.title_id,
    t.advance,
    ((t.price * s.qty)*(t.royalty/100)*(t_a.royaltyper/100)) AS sales_royalty

FROM
    `ironhack-data-analytics.publications.authors` a
INNER JOIN
    `ironhack-data-analytics.publications.titleauthor` t_a
USING 
    (au_id)

LEFT JOIN
    `ironhack-data-analytics.publications.titles` t
USING
    (title_id)

INNER JOIN
    `ironhack-data-analytics.publications.sales` s
USING
    (title_id)

GROUP BY
    s.qty,
    t.royalty,
    t_a.royaltyper,
    t.price,
    a.au_id,
    t_a.title_id,
    t.advance
    
ORDER BY
    t_a.title_id) royalties

GROUP BY
    au_id,
    title_id,
    advance
    
ORDER BY
    title_id) aggregated_royalties

GROUP BY
    au_id,
    advance,
    agg_royalties)
"""

# %%
query_job = client.query(query=query4)
df = query_job.to_dataframe()
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# <ipython-input-23-b3101fc63a34> in <module>
#       1 query_job = client.query(query=query4)
# ----> 2 df = query_job.to_dataframe()
#       3 df.head(20)
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type)
#    2929             ValueError: If the `pandas` library cannot be imported.
#    2930         """
# -> 2931         return self.result().to_dataframe(
#    2932             bqstorage_client=bqstorage_client,
#    2933             dtypes=dtypes,
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry)
#    2861                 If the job did not complete in the given timeout.
#    2862         """
# -> 2863         super(QueryJob, self).result(timeout=timeout)
#    2864         # Return an iterator instead of returning the job.
#    2865         if not self._query_results:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     730             self._begin(retry=retry)
#     731         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 732         return super(_AsyncJob, self).result(timeout=timeout)
#     733
#     734     def cancelled(self):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    2831     def _blocking_poll(self, timeout=None):
#    2832         self._done_timeout = timeout
# -> 2833         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    2834
#    2835     def result(self, timeout=None, page_size=None, retry=DEFAULT_RETRY):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     271                 sleep_generator,
#     272                 self._deadline,
# --> 273                 on_error=on_error,
#     274             )
#     275
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     180     for sleep in sleep_generator:
#     181         try:
# --> 182             return target()
#     183
#     184         # pylint: disable=broad-except
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in done(self, retry)
#    2818                 project=self.project,
#    2819                 timeout_ms=timeout_ms,
# -> 2820                 location=self.location,
#    2821             )
#    2822
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location)
#     875         # QueryJob.result()). So we don't need to poll here.
#     876         resource = self._call_api(
# --> 877             retry, method="GET", path=path, query_params=extra_params
#     878         )
#     879         return _QueryResults.from_api_repr(resource)
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     417         if retry:
#     418             call = retry(call)
# --> 419         return call()
#     420
#     421     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     271                 sleep_generator,
#     272                 self._deadline,
# --> 273                 on_error=on_error,
#     274             )
#     275
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     180     for sleep in sleep_generator:
#     181         try:
# --> 182             return target()
#     183
#     184         # pylint: disable=broad-except
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     394
#     395         if not 200 <= response.status_code < 300:
# --> 396             raise exceptions.from_http_response(response)
#     397
#     398         if expect_json and response.content:
#
# Conflict: 409 GET https://www.googleapis.com/bigquery/v2/projects/ironhack-data-analytics/queries/6ad1331b-0613-44e1-8cb6-8d76e72554a5?maxResults=0&location=US: Already Exists: Table ironhack-data-analytics:publications.most_profiting_authors_dani

# %%
query5 = """
SELECT *
FROM
    `ironhack-data-analytics.publications.most_profiting_authors_dani`
ORDER BY
    profits DESC
"""

# %%
query_job = client.query(query=query5)
df = query_job.to_dataframe()
df.head(20)
# Out:
#          au_id    profits
# 0  899-46-2035  15007.176
# 1  472-27-2349   8008.994
# 2  807-91-6654   7083.800
